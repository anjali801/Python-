# %% [markdown]
# # Python :

# %%
AnjaliSaini = "Student"   # ----> pascal case

anjaliSaini = "Student"   # ----> Camal case

anjali_saini = "Student"  # ----> Snake case

# %%
x =  input("Enter the first number :")
y = input("Enter the second number :")
if x > y :
  print("x is the greater than y ")
else :
  print("y is the greater than x ")

print(f"value of x {x},value of y {y}")
# Out:
# Enter the first number :34
# Enter the second number :41
# y is the greater than x
# value of x 34,value of y 41

# %%
z = input("Enter the Gender : ")
if z == "male" :
  print("Gender is male")
else  :
  print("Gender is female")
# Out:
# Enter the Gender : male
# Gender is male

# %%
w = int(input("Enter the number :"))
if w % 2 == 0 :
  print("the number is even :" , w )
else :
  print("the number is odd :" , w)

# %%
t = int(input("Enter the name :"))
u = int(input("Enter the age : "))
if u > 18 :
  print("you are eligible to vote" , t)
else :
  print("you are not eligible to vote" , t )

# %%
v = input("Enter the year :")
if (v % 4 == 0 ) && (v % 100 != 0) || (v % 400 == 0) :
  print("the year is leap year" , v)
else :
  print("the year is not leap year" , v)

# %%
temp  = input("Enter the temperature : ")
if temp < 0 :
 print("Freezing cold ")
elif temp > 0 and temp < 10 :
 print("Very cold")
elif temp > 10 and temp < 20 :
 print("Cold")
elif temp > 20 and temp < 30 :
 print("Normal")
else :
  print("Hot")
